# %% [markdown]
# #Lab08

# %% [markdown]
# # Transformer with PyTorch

# %% [markdown]
# ## Sequence-to-Sequence Modeling with nn.Transformer and TorchText
# ================================================================================
#
# This sample code is from the [Official Doc of PyTorch](https://pytorch.org/tutorials/beginner/transformer_tutorial.html) for seq2seq modeling using Transformer.

# %%
# The torchtext package is part of the PyTorch project, which consists of data processing utilities and popular datasets for natural language.
# !pip3 install torchtext==0.4.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchtext==0.4.0
#   Downloading torchtext-0.4.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 575.8 kB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (4.65.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (2.0.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.4.0) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.4.0) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.4.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.4.0) (2022.12.7)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (4.5.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (1.11.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->torchtext==0.4.0) (16.0.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->torchtext==0.4.0) (3.25.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torchtext==0.4.0) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->torchtext==0.4.0) (1.3.0)
# Installing collected packages: torchtext
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.15.1
#     Uninstalling torchtext-0.15.1:
#       Successfully uninstalled torchtext-0.15.1
# Successfully installed torchtext-0.4.0

# %% [markdown]
# In this sample code, we will learn about how to train a sequence-to-sequence model
# that uses the
# [nn.Transformer](https://pytorch.org/docs/master/nn.html?highlight=nn%20transformer#torch.nn.Transformer) module.
#
# PyTorch 1.2 release includes a standard transformer module based on the
# paper [Attention is All You
# Need](https://arxiv.org/pdf/1706.03762.pdf) . The transformer model
# has been proved to be superior in quality for many sequence-to-sequence
# problems while being more parallelizable. The ``nn.Transformer`` module
# relies entirely on an attention mechanism (another module recently
# implemented as [nn.MultiheadAttention](https://pytorch.org/docs/master/nn.html?highlight=multiheadattention#torch.nn.MultiheadAttention)) to draw global dependencies
# between input and output. The ``nn.Transformer`` module is now highly
# modularized such that a single component (like `nn.TransformerEncoder`
# in this tutorial) can be easily adapted/composed.
#
#
# Recall: We just practised how to implement the attention mechanism in Lab 7 🤤
#
# ![](https://github.com/pytorch/tutorials/blob/gh-pages/_static/img/transformer_architecture.jpg?raw=1)

# %% [markdown]
# ### Define the model
# ----------------

# %% [markdown]
# In this sample code, we train ``nn.TransformerEncoder`` model on a
# language modeling task. The language modeling task is to assign a
# probability for the likelihood of a given word (or a sequence of words)
# to follow a sequence of words.
#
# A sequence of tokens are passed to the embedding
# layer first, followed by a positional encoding layer to account for the order
# of the word (see the next paragraph for more details). The
# ``nn.TransformerEncoder`` consists of multiple layers of
# [nn.TransformerEncoderLayer](https://pytorch.org/docs/master/nn.html?highlight=transformerencoderlayer#torch.nn.TransformerEncoderLayer) . Along with the input sequence, a square
# attention mask is required because the self-attention layers in
# ``nn.TransformerEncoder`` are only allowed to attend the earlier positions in
# the sequence. For the language modeling task, any tokens on the future
# positions should be masked. To have the actual words, the output
# of ``nn.TransformerEncoder`` model is sent to the final Linear
# layer, which is followed by a log-Softmax function.

# %% [markdown]
# #### Transformer Model

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F

class TransformerModel(nn.Module):

    def __init__(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.5):
        super(TransformerModel, self).__init__()
        from torch.nn import TransformerEncoder, TransformerEncoderLayer
        self.model_type = 'Transformer'
        self.src_mask = None
        self.pos_encoder = PositionalEncoding(ninp, dropout)
        encoder_layers = TransformerEncoderLayer(ninp, nhead, nhid, dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layers, nlayers)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.ninp = ninp
        self.decoder = nn.Linear(ninp, ntoken)

        self.init_weights()

    def _generate_square_subsequent_mask(self, sz):
        #triu returns the upper triangular part of a matrix (2-D tensor) or batch of matrices (see section below)
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, src):
        if self.src_mask is None or self.src_mask.size(0) != len(src):
            device = src.device
            mask = self._generate_square_subsequent_mask(len(src)).to(device)
            self.src_mask = mask

        src = self.encoder(src) * math.sqrt(self.ninp)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src, self.src_mask)
        output = self.decoder(output)
        return output

# %% [markdown]
# ##### Masking
# By passing the mask into the transformer_encoder forward() function, the attention will only be calculated on the earlier positions in the sequence.

# %%
#triu returns the upper triangular part of a matrix (2-D tensor) or batch of matrices (see section below)
torch.triu(torch.ones(3, 3))
# Out:
# tensor([[1., 1., 1.],
#         [0., 1., 1.],
#         [0., 0., 1.]])

# %%
# Masking
def masking():
  sz = 4
  mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
  mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
  
  return mask

masking()
# Out:
# tensor([[0., -inf, -inf, -inf],
#         [0., 0., -inf, -inf],
#         [0., 0., 0., -inf],
#         [0., 0., 0., 0.]])

# %% [markdown]
# #### Positional Encoding

# %% [markdown]
# Transformer architecture takes base architecture of Seq2Seq model (Encoder - Decoder). However, the transformer does not use recurrent model so this means we need a module that captures sequence information of the input/output.
#
# ``PositionalEncoding`` module injects some information about the
# relative or absolute position of the tokens in the sequence. The
# positional encodings have the same dimension as the embeddings so that
# the two can be summed. Here, we use ``sine`` and ``cosine`` functions of
# different frequencies.

# %%
class PositionalEncoding(nn.Module):

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term) #0::2 means starting with index 0, step = 2
        pe[:, 1::2] = torch.cos(position * div_term) 
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

# %% [markdown]
# ### Load and batch data
# -------------------

# %% [markdown]
# The training process uses Wikitext-2 dataset from ``torchtext``. The
# vocab object is built based on the train dataset and is used to numericalize
# tokens into tensors. Starting from sequential data, the ``batchify()``
# function arranges the dataset into columns, trimming off any tokens remaining
# after the data has been divided into batches of size ``batch_size``.
# For instance, with the alphabet as the sequence (total length of 26)
# and a batch size of 4, we would divide the alphabet into 4 sequences of
# length 6:
#
# \begin{align}\begin{bmatrix}
#   \text{A} & \text{B} & \text{C} & \ldots & \text{X} & \text{Y} & \text{Z}
#   \end{bmatrix}
#   \Rightarrow
#   \begin{bmatrix}
#   \begin{bmatrix}\text{A} \\ \text{B} \\ \text{C} \\ \text{D} \\ \text{E} \\ \text{F}\end{bmatrix} &
#   \begin{bmatrix}\text{G} \\ \text{H} \\ \text{I} \\ \text{J} \\ \text{K} \\ \text{L}\end{bmatrix} &
#   \begin{bmatrix}\text{M} \\ \text{N} \\ \text{O} \\ \text{P} \\ \text{Q} \\ \text{R}\end{bmatrix} &
#   \begin{bmatrix}\text{S} \\ \text{T} \\ \text{U} \\ \text{V} \\ \text{W} \\ \text{X}\end{bmatrix}
#   \end{bmatrix}\end{align}
#
# These columns are treated as independent by the model, which means that
# the dependence of ``G`` and ``F`` can not be learned, but allows more
# efficient batch processing.

# %%
import torchtext
from torchtext.data.utils import get_tokenizer
TEXT = torchtext.data.Field(tokenize=get_tokenizer("basic_english"),
                            init_token='<sos>',
                            eos_token='<eos>',
                            lower=True)
train_txt, val_txt, test_txt = torchtext.datasets.WikiText2.splits(TEXT)
TEXT.build_vocab(train_txt)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def batchify(data, bsz):
    data = TEXT.numericalize([data.examples[0].text])
    # Divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    return data.to(device)

batch_size = 20
eval_batch_size = 10
train_data = batchify(train_txt, batch_size)
val_data = batchify(val_txt, eval_batch_size)
test_data = batchify(test_txt, eval_batch_size)
# Out:
# downloading wikitext-2-v1.zip
# wikitext-2-v1.zip: 100%|██████████| 4.48M/4.48M [00:01<00:00, 2.89MB/s]
# extracting

# %% [markdown]
# Functions to generate input and target sequence

# %% [markdown]
# ``get_batch()`` function generates the input and target sequence for
# the transformer model. It subdivides the source data into chunks of
# length ``bptt``. For the language modeling task, the model needs the
# following words as ``Target``. For example, with a ``bptt`` value of 2,
# we’d get the following two Variables for ``i`` = 0:
#
# ![](https://github.com/pytorch/tutorials/blob/gh-pages/_static/img/transformer_input_target.png?raw=1)
#
#
# It should be noted that the chunks are along dimension 0, consistent
# with the ``S`` dimension in the Transformer model. The batch dimension
# ``N`` is along dimension 1.

# %%
bptt = 35
def get_batch(source, i):
    seq_len = min(bptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target

# %% [markdown]
# ### Initiate an instance
# --------------------

# %% [markdown]
# The model is set up with the hyperparameter below. The vocab size is
# equal to the length of the vocab object.

# %%
ntokens = len(TEXT.vocab.stoi) # the size of vocabulary
emsize = 200 # embedding dimension
nhid = 200 # the dimension of the feedforward network model in nn.TransformerEncoder
nlayers = 2 # the number of nn.TransformerEncoderLayer in nn.TransformerEncoder
nhead = 2 # the number of heads in the multiheadattention models
dropout = 0.2 # the dropout value
model = TransformerModel(ntokens, emsize, nhead, nhid, nlayers, dropout).to(device)

# %% [markdown]
# ### Run the model
# -------------

# %% [markdown]
# `CrossEntropyLoss `
# is applied to track the loss and
# `SGD `
# implements stochastic gradient descent method as the optimizer. The initial
# learning rate is set to 5.0. `StepLR ` is
# applied to adjust the learning rate through epochs. During the
# training, we use
# `nn.utils.clip_grad_norm_ `
# function to scale all the gradient together to prevent exploding.

# %%
criterion = nn.CrossEntropyLoss()
lr = 5.0 # learning rate
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

import time
def train():

    model.train() # Turn on the train mode
    total_loss = 0.
    start_time = time.time()
    ntokens = len(TEXT.vocab.stoi)
    for batch, i in enumerate(range(0, train_data.size(0) - 1, bptt)):
        data, targets = get_batch(train_data, i)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output.view(-1, ntokens), targets)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()

        total_loss += loss.item()
        log_interval = 200
        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  'lr {:02.2f} | ms/batch {:5.2f} | '
                  'loss {:5.2f} | ppl {:8.2f}'.format(
                    epoch, batch, len(train_data) // bptt, scheduler.get_lr()[0],
                    elapsed * 1000 / log_interval,
                    cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()


def evaluate(eval_model, data_source):
    eval_model.eval() # Turn on the evaluation mode
    total_loss = 0.
    ntokens = len(TEXT.vocab.stoi)
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, bptt):
            data, targets = get_batch(data_source, i)
            output = eval_model(data)
            output_flat = output.view(-1, ntokens)
            total_loss += len(data) * criterion(output_flat, targets).item()
    return total_loss / (len(data_source) - 1)

# %% [markdown]
# Loop over epochs. Save the model if the validation loss is the best
# we've seen so far. Adjust the learning rate after each epoch.

# %%
best_val_loss = float("inf")
epochs = 3 # The number of epochs
best_model = None

for epoch in range(1, epochs + 1):
    epoch_start_time = time.time()
    train()
    val_loss = evaluate(model, val_data)
    print('-' * 89)
    print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
          'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                     val_loss, math.exp(val_loss)))
    print('-' * 89)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = model

    scheduler.step()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:389: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# | epoch   1 |   200/ 2981 batches | lr 5.00 | ms/batch 31.20 | loss  8.02 | ppl  3027.78
# | epoch   1 |   400/ 2981 batches | lr 5.00 | ms/batch 13.82 | loss  6.78 | ppl   883.67
# | epoch   1 |   600/ 2981 batches | lr 5.00 | ms/batch 13.85 | loss  6.37 | ppl   582.36
# | epoch   1 |   800/ 2981 batches | lr 5.00 | ms/batch 13.85 | loss  6.23 | ppl   505.58
# | epoch   1 |  1000/ 2981 batches | lr 5.00 | ms/batch 14.24 | loss  6.11 | ppl   451.36
# | epoch   1 |  1200/ 2981 batches | lr 5.00 | ms/batch 14.14 | loss  6.09 | ppl   441.39
# | epoch   1 |  1400/ 2981 batches | lr 5.00 | ms/batch 13.96 | loss  6.04 | ppl   421.31
# | epoch   1 |  1600/ 2981 batches | lr 5.00 | ms/batch 13.96 | loss  6.05 | ppl   424.28
# | epoch   1 |  1800/ 2981 batches | lr 5.00 | ms/batch 14.09 | loss  5.96 | ppl   387.94
# | epoch   1 |  2000/ 2981 batches | lr 5.00 | ms/batch 14.57 | loss  5.96 | ppl   386.27
# | epoch   1 |  2200/ 2981 batches | lr 5.00 | ms/batch 14.14 | loss  5.85 | ppl   346.45
# | epoch   1 |  2400/ 2981 batches | lr 5.00 | ms/batch 14.12 | loss  5.90 | ppl   363.36
# | epoch   1 |  2600/ 2981 batches | lr 5.00 | ms/batch 14.09 | loss  5.89 | ppl   363.00
# | epoch   1 |  2800/ 2981 batches | lr 5.00 | ms/batch 14.67 | loss  5.80 | ppl   330.61
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 47.59s | valid loss  5.72 | valid ppl   303.58
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/ 2981 batches | lr 4.51 | ms/batch 14.34 | loss  5.80 | ppl   330.27
# | epoch   2 |   400/ 2981 batches | lr 4.51 | ms/batch 14.42 | loss  5.77 | ppl   321.65
# | epoch   2 |   600/ 2981 batches | lr 4.51 | ms/batch 14.73 | loss  5.60 | ppl   269.93
# | epoch   2 |   800/ 2981 batches | lr 4.51 | ms/batch 14.44 | loss  5.64 | ppl   280.64
# | epoch   2 |  1000/ 2981 batches | lr 4.51 | ms/batch 14.43 | loss  5.59 | ppl   266.59
# | epoch   2 |  1200/ 2981 batches | lr 4.51 | ms/batch 14.46 | loss  5.62 | ppl   275.35
# | epoch   2 |  1400/ 2981 batches | lr 4.51 | ms/batch 14.89 | loss  5.62 | ppl   276.86
# | epoch   2 |  1600/ 2981 batches | lr 4.51 | ms/batch 14.58 | loss  5.66 | ppl   287.47
# | epoch   2 |  1800/ 2981 batches | lr 4.51 | ms/batch 14.46 | loss  5.60 | ppl   269.43
# | epoch   2 |  2000/ 2981 batches | lr 4.51 | ms/batch 14.48 | loss  5.62 | ppl   275.38
# | epoch   2 |  2200/ 2981 batches | lr 4.51 | ms/batch 15.01 | loss  5.51 | ppl   246.24
# | epoch   2 |  2400/ 2981 batches | lr 4.51 | ms/batch 14.54 | loss  5.58 | ppl   265.19
# | epoch   2 |  2600/ 2981 batches | lr 4.51 | ms/batch 14.41 | loss  5.59 | ppl   267.97
# | epoch   2 |  2800/ 2981 batches | lr 4.51 | ms/batch 14.40 | loss  5.52 | ppl   248.49
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 45.71s | valid loss  5.58 | valid ppl   264.03
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/ 2981 batches | lr 4.29 | ms/batch 14.46 | loss  5.55 | ppl   257.87
# | epoch   3 |   400/ 2981 batches | lr 4.29 | ms/batch 14.38 | loss  5.56 | ppl   258.82
# | epoch   3 |   600/ 2981 batches | lr 4.29 | ms/batch 14.36 | loss  5.37 | ppl   215.22
# | epoch   3 |   800/ 2981 batches | lr 4.29 | ms/batch 16.79 | loss  5.42 | ppl   225.59
# | epoch   3 |  1000/ 2981 batches | lr 4.29 | ms/batch 18.80 | loss  5.38 | ppl   217.53
# | epoch   3 |  1200/ 2981 batches | lr 4.29 | ms/batch 14.36 | loss  5.41 | ppl   223.36
# | epoch   3 |  1400/ 2981 batches | lr 4.29 | ms/batch 14.34 | loss  5.43 | ppl   229.03
# | epoch   3 |  1600/ 2981 batches | lr 4.29 | ms/batch 14.86 | loss  5.48 | ppl   240.97
# | epoch   3 |  1800/ 2981 batches | lr 4.29 | ms/batch 14.32 | loss  5.41 | ppl   223.12
# | epoch   3 |  2000/ 2981 batches | lr 4.29 | ms/batch 14.27 | loss  5.43 | ppl   229.07
# | epoch   3 |  2200/ 2981 batches | lr 4.29 | ms/batch 14.31 | loss  5.32 | ppl   205.21
# | epoch   3 |  2400/ 2981 batches | lr 4.29 | ms/batch 14.80 | loss  5.39 | ppl   218.44
# | epoch   3 |  2600/ 2981 batches | lr 4.29 | ms/batch 14.39 | loss  5.41 | ppl   223.79
# | epoch   3 |  2800/ 2981 batches | lr 4.29 | ms/batch 14.34 | loss  5.33 | ppl   207.36
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 46.41s | valid loss  5.56 | valid ppl   260.31
# -----------------------------------------------------------------------------------------

# %% [markdown]
# ### Evaluate the model with the test dataset
# -------------------------------------
#
# Apply the best model to check the result with the test dataset.

# %%
test_loss = evaluate(best_model, test_data)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.2f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)
# Out:
# =========================================================================================
# | End of training | test loss  5.47 | test ppl   236.98
# =========================================================================================

# %% [markdown]
# # Lab 8 Exercise
# Please complete the following **question E1** for Lab 8 and check with your Tutor (Lab Facilitator) in the lab.
#
# **Submission Due**: Your Lab 9 (in Week 10)
#
# **Submission Method**: Show your final code to your tutor during the Lab.

# %% [markdown]
# ## E1. Test with Transformer
# Try ***either*** different number of `heads` in Multi-head Attention, ***or*** different number of `encoders`, and record the test performance (Try `at least 3 variants`). Then visualise a table/graph with the peformance to show ***either*** the test performance (or validation losses/ppls) VS. number of heads, ***or*** the test performance (or validation losses/ppls) VS. number of encoders (you can keep epochs = 3 for all experiments).

# %% [markdown]
# Below are two examples for graph plotting and table printing as demonstration. The graph 1 plots the bar chart where the x-axis is the number of attention heads and y-axis indicates the test ppl value. The graph 2 draws multiple line graphs in one figure, in which each line shows the validation loss over each epoch (x-axis is the epoch number, y-axis is the validation loss value). Similarly, the two tables prints the same information but in the table format.

# %% [markdown]
# ## Graph 1 / Table 1 demonstration

# %%
import matplotlib.pyplot as plt

plt.title("Test performance - Number of heads") # Set graph/figure title
plt.ylabel("Test ppl") # Set y-axis title
plt.xlabel("Number of heads") # Set x-axis title

heads = [1,2,4,8] # assume we try head number of 1, 2, 4, and 8 (i.e., 4 variants)
ppls = [400,300,200,100] # assume we get the corresponding test ppl using each variant head number - you need to get them from your own experiments
plt.bar(heads,ppls) # plot the bar chart

plt.show() # show the bar chart

# More details of .bar() plotting can be found from: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html

# %%
from tabulate import tabulate
heads = [1,2,4,8] # assume we try head number of 1, 2, 4, and 8 (i.e., 4 variants)
ppls = [400,300,200,100] # assume we get the corresponding test ppl using each variant head number - you need to get them from your own experiments
table = [['']+['head '+str(i) for i in heads], ['Test ppl']+ppls]
print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒══════════╤══════════╤══════════╤══════════╤══════════╕
# │          │   head 1 │   head 2 │   head 4 │   head 8 │
# ╞══════════╪══════════╪══════════╪══════════╪══════════╡
# │ Test ppl │      400 │      300 │      200 │      100 │
# ╘══════════╧══════════╧══════════╧══════════╧══════════╛

# %% [markdown]
# ## Graph 2 / Table 2 demonstration

# %%
import matplotlib.pyplot as plt
import random

plt.title("Validation performance - Number of encoders") # Set graph/figure title
plt.ylabel("Validation performance") # Set y-axis title
plt.xlabel("Number of epochs") # Set x-axis title

encoders = [2,4,6,8] # assume we tried 4 variants of encoder layers

for encoder in encoders: # for each encoder variant, we will draw one line graph, showing the validation loss of each epoch
  epochs = [1,2,3] # for each variant, we apply 3 epochs. Thus, we will have epoch 1, 2, 3 (or 0, 1, 2 if you starts with 0)
  val_losses = [random.randint(1, 3), random.randint(1, 3), random.randint(1, 3)] # for each epoch, we recorded the validation loss. Note that here we apply random numbers only for demonstration. However, you need to record your real validation loss if needed.
  plt.plot(epochs,val_losses, label="{0} encoders".format(encoder)) # label each line graph with the encoder number (see the actual plotting in the graph below)

plt.legend(); # this turns on the legends, which shows the label for each line graph. You can comment it out and rerun the code to see the difference
plt.show() # show the final figure

# More details of .plot() plotting can be found from: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
from tabulate import tabulate

table=[]
epochs = [1,2,3] # for each variant, we apply 3 epochs. Thus, we will have epoch 1, 2, 3 (or 0, 1, 2 if you starts with 0)

table.append(['']+['epoch '+str(i) for i in encoders]) # append encoder numbers as header

for encoder in encoders: # for each encoder variant, we will have validation loss for each epoch
  
  val_losses = [random.randint(1, 3), random.randint(1, 3), random.randint(1, 3)] # for each epoch, we recorded the validation loss. Note that here we apply random numbers only for demonstration. However, you need to record your real validation loss if needed.
  table.append(['encoder '+str(encoder)]+val_losses) # append each row data to the table

print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒═══════════╤═══════════╤═══════════╤═══════════╕
# │           │   epoch 2 │   epoch 4 │   epoch 6 │
# ╞═══════════╪═══════════╪═══════════╪═══════════╡
# │ encoder 2 │         1 │         2 │         2 │
# ├───────────┼───────────┼───────────┼───────────┤
# │ encoder 4 │         2 │         2 │         1 │
# ├───────────┼───────────┼───────────┼───────────┤
# │ encoder 6 │         2 │         2 │         3 │
# ├───────────┼───────────┼───────────┼───────────┤
# │ encoder 8 │         2 │         1 │         2 │
# ╘═══════════╧═══════════╧═══════════╧═══════════╛

# %% [markdown]
# ## Your solution

# %% [markdown]
# Hint: You can easily change the head/encoder number and train the model using the sample code above. For each training, all you need to do is to record the values you need for visualization, e.g., the x and y values if you are using graphs, or the header and row data if you are using tables. Then you can use the graph or table demonstration code to visualize it.

# %%
nhead_list = [2,4,8] # the number of heads in the multiheadattention models

# Define an empty list to store the results
ppls_list = []
val_loss_list = []

# Loop over each value in the original list
for value in nhead_list:
    model = TransformerModel(ntokens, emsize, value, nhid, nlayers, dropout).to(device)

    best_val_loss = float("inf")
    epochs = 3 # The number of epochs
    best_model = None
    val_loss_list_eachepoch=[]
    for epoch in range(1, epochs + 1):
        epoch_start_time = time.time()
        train()
        val_loss = evaluate(model, val_data)
        val_loss_list_eachepoch.append(val_loss)
    
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = model
    
        scheduler.step()
    val_loss_list.append(val_loss_list_eachepoch)

    test_loss = evaluate(best_model, test_data)
    result = math.exp(test_loss)

    ppls_list.append(result)

# Print lists
print(nhead_list)
print(ppls_list)
print(val_loss_list)
#model = TransformerModel(ntokens, emsize, nhead, nhid, nlayers, dropout).to(device)
#test_loss = evaluate(best_model, test_data)
#ppls_4 = math.exp(test_loss)
#print(nhead_4,ppls_4)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:389: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# | epoch   1 |   200/ 2981 batches | lr 1.62 | ms/batch 14.47 | loss 10.68 | ppl 43540.43
# | epoch   1 |   400/ 2981 batches | lr 1.62 | ms/batch 14.06 | loss 10.63 | ppl 41179.65
# | epoch   1 |   600/ 2981 batches | lr 1.62 | ms/batch 14.05 | loss 10.62 | ppl 41073.76
# | epoch   1 |   800/ 2981 batches | lr 1.62 | ms/batch 14.49 | loss 10.63 | ppl 41315.76
# | epoch   1 |  1000/ 2981 batches | lr 1.62 | ms/batch 14.13 | loss 10.63 | ppl 41350.10
# | epoch   1 |  1200/ 2981 batches | lr 1.62 | ms/batch 14.13 | loss 10.63 | ppl 41408.92
# | epoch   1 |  1400/ 2981 batches | lr 1.62 | ms/batch 14.24 | loss 10.63 | ppl 41435.68
# | epoch   1 |  1600/ 2981 batches | lr 1.62 | ms/batch 14.45 | loss 10.63 | ppl 41357.82
# | epoch   1 |  1800/ 2981 batches | lr 1.62 | ms/batch 14.54 | loss 10.63 | ppl 41481.34
# | epoch   1 |  2000/ 2981 batches | lr 1.62 | ms/batch 15.25 | loss 10.63 | ppl 41515.27
# | epoch   1 |  2200/ 2981 batches | lr 1.62 | ms/batch 16.05 | loss 10.63 | ppl 41349.26
# | epoch   1 |  2400/ 2981 batches | lr 1.62 | ms/batch 14.61 | loss 10.62 | ppl 41119.98
# | epoch   1 |  2600/ 2981 batches | lr 1.62 | ms/batch 14.77 | loss 10.63 | ppl 41188.78
# | epoch   1 |  2800/ 2981 batches | lr 1.62 | ms/batch 14.46 | loss 10.63 | ppl 41214.45
# | epoch   2 |   200/ 2981 batches | lr 1.54 | ms/batch 16.04 | loss 10.68 | ppl 43597.71
# | epoch   2 |   400/ 2981 batches | lr 1.54 | ms/batch 14.64 | loss 10.63 | ppl 41324.90
# | epoch   2 |   600/ 2981 batches | lr 1.54 | ms/batch 14.60 | loss 10.62 | ppl 41113.13
# | epoch   2 |   800/ 2981 batches | lr 1.54 | ms/batch 14.59 | loss 10.63 | ppl 41409.91
# | epoch   2 |  1000/ 2981 batches | lr 1.54 | ms/batch 14.82 | loss 10.63 | ppl 41315.57
# | epoch   2 |  1200/ 2981 batches | lr 1.54 | ms/batch 15.03 | loss 10.63 | ppl 41508.91
# | epoch   2 |  1400/ 2981 batches | lr 1.54 | ms/batch 15.13 | loss 10.63 | ppl 41413.23
# | epoch   2 |  1600/ 2981 batches | lr 1.54 | ms/batch 14.54 | loss 10.63 | ppl 41270.26
# | epoch   2 |  1800/ 2981 batches | lr 1.54 | ms/batch 14.65 | loss 10.63 | ppl 41401.46
# | epoch   2 |  2000/ 2981 batches | lr 1.54 | ms/batch 14.72 | loss 10.63 | ppl 41490.15
# | epoch   2 |  2200/ 2981 batches | lr 1.54 | ms/batch 14.42 | loss 10.63 | ppl 41405.63
# | epoch   2 |  2400/ 2981 batches | lr 1.54 | ms/batch 14.37 | loss 10.62 | ppl 41142.88
# | epoch   2 |  2600/ 2981 batches | lr 1.54 | ms/batch 14.49 | loss 10.62 | ppl 41142.80
# | epoch   2 |  2800/ 2981 batches | lr 1.54 | ms/batch 14.79 | loss 10.63 | ppl 41159.56
# | epoch   3 |   200/ 2981 batches | lr 1.46 | ms/batch 14.36 | loss 10.68 | ppl 43624.18
# | epoch   3 |   400/ 2981 batches | lr 1.46 | ms/batch 14.61 | loss 10.63 | ppl 41216.56
# | epoch   3 |   600/ 2981 batches | lr 1.46 | ms/batch 14.61 | loss 10.62 | ppl 40998.98
# | epoch   3 |   800/ 2981 batches | lr 1.46 | ms/batch 14.33 | loss 10.63 | ppl 41355.77
# | epoch   3 |  1000/ 2981 batches | lr 1.46 | ms/batch 14.29 | loss 10.63 | ppl 41351.97
# | epoch   3 |  1200/ 2981 batches | lr 1.46 | ms/batch 14.52 | loss 10.63 | ppl 41516.61
# | epoch   3 |  1400/ 2981 batches | lr 1.46 | ms/batch 14.67 | loss 10.63 | ppl 41467.27
# | epoch   3 |  1600/ 2981 batches | lr 1.46 | ms/batch 14.37 | loss 10.63 | ppl 41238.26
# | epoch   3 |  1800/ 2981 batches | lr 1.46 | ms/batch 14.41 | loss 10.63 | ppl 41428.07
# | epoch   3 |  2000/ 2981 batches | lr 1.46 | ms/batch 14.45 | loss 10.63 | ppl 41486.30
# | epoch   3 |  2200/ 2981 batches | lr 1.46 | ms/batch 14.84 | loss 10.63 | ppl 41329.91
# | epoch   3 |  2400/ 2981 batches | lr 1.46 | ms/batch 14.47 | loss 10.63 | ppl 41225.14
# | epoch   3 |  2600/ 2981 batches | lr 1.46 | ms/batch 14.41 | loss 10.63 | ppl 41152.21
# | epoch   3 |  2800/ 2981 batches | lr 1.46 | ms/batch 14.43 | loss 10.62 | ppl 41114.93
# | epoch   1 |   200/ 2981 batches | lr 1.39 | ms/batch 14.44 | loss 10.55 | ppl 38278.38
# | epoch   1 |   400/ 2981 batches | lr 1.39 | ms/batch 14.40 | loss 10.51 | ppl 36718.42
# | epoch   1 |   600/ 2981 batches | lr 1.39 | ms/batch 14.88 | loss 10.50 | ppl 36456.66
# | epoch   1 |   800/ 2981 batches | lr 1.39 | ms/batch 14.52 | loss 10.51 | ppl 36675.50
# | epoch   1 |  1000/ 2981 batches | lr 1.39 | ms/batch 14.43 | loss 10.51 | ppl 36752.48
# | epoch   1 |  1200/ 2981 batches | lr 1.39 | ms/batch 14.47 | loss 10.51 | ppl 36570.53
# | epoch   1 |  1400/ 2981 batches | lr 1.39 | ms/batch 14.92 | loss 10.50 | ppl 36347.38
# | epoch   1 |  1600/ 2981 batches | lr 1.39 | ms/batch 14.42 | loss 10.50 | ppl 36478.41
# | epoch   1 |  1800/ 2981 batches | lr 1.39 | ms/batch 14.42 | loss 10.51 | ppl 36629.40
# | epoch   1 |  2000/ 2981 batches | lr 1.39 | ms/batch 14.41 | loss 10.51 | ppl 36736.71
# | epoch   1 |  2200/ 2981 batches | lr 1.39 | ms/batch 15.80 | loss 10.51 | ppl 36523.44
# | epoch   1 |  2400/ 2981 batches | lr 1.39 | ms/batch 14.58 | loss 10.50 | ppl 36356.23
# | epoch   1 |  2600/ 2981 batches | lr 1.39 | ms/batch 14.43 | loss 10.50 | ppl 36462.09
# | epoch   1 |  2800/ 2981 batches | lr 1.39 | ms/batch 14.42 | loss 10.50 | ppl 36464.03
# | epoch   2 |   200/ 2981 batches | lr 1.32 | ms/batch 15.32 | loss 10.55 | ppl 38329.29
# | epoch   2 |   400/ 2981 batches | lr 1.32 | ms/batch 14.40 | loss 10.51 | ppl 36634.51
# | epoch   2 |   600/ 2981 batches | lr 1.32 | ms/batch 14.39 | loss 10.50 | ppl 36455.59
# | epoch   2 |   800/ 2981 batches | lr 1.32 | ms/batch 14.93 | loss 10.51 | ppl 36636.85
# | epoch   2 |  1000/ 2981 batches | lr 1.32 | ms/batch 14.39 | loss 10.51 | ppl 36796.90
# | epoch   2 |  1200/ 2981 batches | lr 1.32 | ms/batch 14.38 | loss 10.50 | ppl 36486.07
# | epoch   2 |  1400/ 2981 batches | lr 1.32 | ms/batch 14.37 | loss 10.50 | ppl 36270.31
# | epoch   2 |  1600/ 2981 batches | lr 1.32 | ms/batch 14.66 | loss 10.51 | ppl 36553.91
# | epoch   2 |  1800/ 2981 batches | lr 1.32 | ms/batch 14.56 | loss 10.51 | ppl 36596.81
# | epoch   2 |  2000/ 2981 batches | lr 1.32 | ms/batch 14.34 | loss 10.51 | ppl 36662.75
# | epoch   2 |  2200/ 2981 batches | lr 1.32 | ms/batch 14.40 | loss 10.51 | ppl 36551.33
# | epoch   2 |  2400/ 2981 batches | lr 1.32 | ms/batch 14.56 | loss 10.50 | ppl 36388.27
# | epoch   2 |  2600/ 2981 batches | lr 1.32 | ms/batch 14.70 | loss 10.51 | ppl 36566.25
# | epoch   2 |  2800/ 2981 batches | lr 1.32 | ms/batch 14.35 | loss 10.50 | ppl 36418.57
# | epoch   3 |   200/ 2981 batches | lr 1.25 | ms/batch 14.93 | loss 10.55 | ppl 38263.41
# | epoch   3 |   400/ 2981 batches | lr 1.25 | ms/batch 14.51 | loss 10.51 | ppl 36612.29
# | epoch   3 |   600/ 2981 batches | lr 1.25 | ms/batch 14.39 | loss 10.50 | ppl 36454.07
# | epoch   3 |   800/ 2981 batches | lr 1.25 | ms/batch 14.37 | loss 10.51 | ppl 36556.47
# | epoch   3 |  1000/ 2981 batches | lr 1.25 | ms/batch 14.63 | loss 10.51 | ppl 36793.99
# | epoch   3 |  1200/ 2981 batches | lr 1.25 | ms/batch 14.74 | loss 10.51 | ppl 36566.78
# | epoch   3 |  1400/ 2981 batches | lr 1.25 | ms/batch 14.41 | loss 10.50 | ppl 36276.21
# | epoch   3 |  1600/ 2981 batches | lr 1.25 | ms/batch 14.39 | loss 10.51 | ppl 36598.46
# | epoch   3 |  1800/ 2981 batches | lr 1.25 | ms/batch 14.49 | loss 10.51 | ppl 36606.77
# | epoch   3 |  2000/ 2981 batches | lr 1.25 | ms/batch 14.80 | loss 10.51 | ppl 36654.94
# | epoch   3 |  2200/ 2981 batches | lr 1.25 | ms/batch 14.39 | loss 10.51 | ppl 36595.55
# | epoch   3 |  2400/ 2981 batches | lr 1.25 | ms/batch 14.35 | loss 10.50 | ppl 36346.50
# | epoch   3 |  2600/ 2981 batches | lr 1.25 | ms/batch 14.39 | loss 10.50 | ppl 36439.02
# | epoch   3 |  2800/ 2981 batches | lr 1.25 | ms/batch 14.89 | loss 10.50 | ppl 36378.81
# | epoch   1 |   200/ 2981 batches | lr 1.19 | ms/batch 14.62 | loss 10.66 | ppl 42702.86
# | epoch   1 |   400/ 2981 batches | lr 1.19 | ms/batch 14.84 | loss 10.61 | ppl 40343.45
# | epoch   1 |   600/ 2981 batches | lr 1.19 | ms/batch 14.42 | loss 10.61 | ppl 40593.57
# | epoch   1 |   800/ 2981 batches | lr 1.19 | ms/batch 14.42 | loss 10.61 | ppl 40530.57
# | epoch   1 |  1000/ 2981 batches | lr 1.19 | ms/batch 14.43 | loss 10.61 | ppl 40437.45
# | epoch   1 |  1200/ 2981 batches | lr 1.19 | ms/batch 14.94 | loss 10.61 | ppl 40389.80
# | epoch   1 |  1400/ 2981 batches | lr 1.19 | ms/batch 14.48 | loss 10.61 | ppl 40490.28
# | epoch   1 |  1600/ 2981 batches | lr 1.19 | ms/batch 14.44 | loss 10.61 | ppl 40364.05
# | epoch   1 |  1800/ 2981 batches | lr 1.19 | ms/batch 14.42 | loss 10.61 | ppl 40616.63
# | epoch   1 |  2000/ 2981 batches | lr 1.19 | ms/batch 14.86 | loss 10.61 | ppl 40346.29
# | epoch   1 |  2200/ 2981 batches | lr 1.19 | ms/batch 14.55 | loss 10.61 | ppl 40505.62
# | epoch   1 |  2400/ 2981 batches | lr 1.19 | ms/batch 14.41 | loss 10.61 | ppl 40512.43
# | epoch   1 |  2600/ 2981 batches | lr 1.19 | ms/batch 14.43 | loss 10.61 | ppl 40388.35
# | epoch   1 |  2800/ 2981 batches | lr 1.19 | ms/batch 14.67 | loss 10.61 | ppl 40476.00
# | epoch   2 |   200/ 2981 batches | lr 1.13 | ms/batch 14.48 | loss 10.66 | ppl 42761.33
# | epoch   2 |   400/ 2981 batches | lr 1.13 | ms/batch 14.44 | loss 10.61 | ppl 40473.30
# | epoch   2 |   600/ 2981 batches | lr 1.13 | ms/batch 14.96 | loss 10.61 | ppl 40560.02
# | epoch   2 |   800/ 2981 batches | lr 1.13 | ms/batch 14.42 | loss 10.61 | ppl 40598.76
# | epoch   2 |  1000/ 2981 batches | lr 1.13 | ms/batch 14.46 | loss 10.61 | ppl 40396.76
# | epoch   2 |  1200/ 2981 batches | lr 1.13 | ms/batch 14.47 | loss 10.61 | ppl 40439.03
# | epoch   2 |  1400/ 2981 batches | lr 1.13 | ms/batch 14.75 | loss 10.61 | ppl 40480.43
# | epoch   2 |  1600/ 2981 batches | lr 1.13 | ms/batch 14.41 | loss 10.61 | ppl 40366.06
# | epoch   2 |  1800/ 2981 batches | lr 1.13 | ms/batch 14.44 | loss 10.62 | ppl 40743.10
# | epoch   2 |  2000/ 2981 batches | lr 1.13 | ms/batch 14.41 | loss 10.60 | ppl 40233.41
# | epoch   2 |  2200/ 2981 batches | lr 1.13 | ms/batch 14.73 | loss 10.61 | ppl 40416.86
# | epoch   2 |  2400/ 2981 batches | lr 1.13 | ms/batch 14.43 | loss 10.61 | ppl 40507.07
# | epoch   2 |  2600/ 2981 batches | lr 1.13 | ms/batch 14.40 | loss 10.61 | ppl 40340.31
# | epoch   2 |  2800/ 2981 batches | lr 1.13 | ms/batch 14.41 | loss 10.61 | ppl 40428.64
# | epoch   3 |   200/ 2981 batches | lr 1.07 | ms/batch 14.48 | loss 10.66 | ppl 42720.15
# | epoch   3 |   400/ 2981 batches | lr 1.07 | ms/batch 14.40 | loss 10.61 | ppl 40467.30
# | epoch   3 |   600/ 2981 batches | lr 1.07 | ms/batch 14.67 | loss 10.61 | ppl 40545.69
# | epoch   3 |   800/ 2981 batches | lr 1.07 | ms/batch 14.57 | loss 10.61 | ppl 40557.97
# | epoch   3 |  1000/ 2981 batches | lr 1.07 | ms/batch 14.44 | loss 10.61 | ppl 40358.65
# | epoch   3 |  1200/ 2981 batches | lr 1.07 | ms/batch 14.37 | loss 10.61 | ppl 40402.84
# | epoch   3 |  1400/ 2981 batches | lr 1.07 | ms/batch 14.60 | loss 10.61 | ppl 40462.08
# | epoch   3 |  1600/ 2981 batches | lr 1.07 | ms/batch 14.52 | loss 10.60 | ppl 40333.47
# | epoch   3 |  1800/ 2981 batches | lr 1.07 | ms/batch 14.45 | loss 10.61 | ppl 40670.88
# | epoch   3 |  2000/ 2981 batches | lr 1.07 | ms/batch 14.42 | loss 10.60 | ppl 40261.96
# | epoch   3 |  2200/ 2981 batches | lr 1.07 | ms/batch 14.65 | loss 10.61 | ppl 40485.34
# | epoch   3 |  2400/ 2981 batches | lr 1.07 | ms/batch 14.48 | loss 10.61 | ppl 40499.20
# | epoch   3 |  2600/ 2981 batches | lr 1.07 | ms/batch 14.41 | loss 10.61 | ppl 40432.47
# | epoch   3 |  2800/ 2981 batches | lr 1.07 | ms/batch 14.43 | loss 10.61 | ppl 40444.87
# [2, 4, 8]
# [42041.973696116525, 35253.38682627399, 40236.991964563305]
# [[10.638747338196014, 10.638747338196014, 10.638747338196014], [10.469485250986406, 10.469485250986406, 10.469485250986406], [10.597400795027674, 10.597400795027674, 10.597400795027674]]

# %%
import matplotlib.pyplot as plt

plt.title("Test performance - Number of heads") # Set graph/figure title
plt.ylabel("Test ppl") # Set y-axis title
plt.xlabel("Number of heads") # Set x-axis title

plt.bar(nhead_list,ppls_list) # plot the bar chart

plt.show() # show the bar chart

# %%
import matplotlib.pyplot as plt
import random

plt.title("Validation performance - Number of heads") # Set graph/figure title
plt.ylabel("Validation performance") # Set y-axis title
plt.xlabel("Number of heads") # Set x-axis title



for index, heads in enumerate(nhead_list): # for each encoder variant, we will draw one line graph, showing the validation loss of each epoch
  epochs = [1,2,3] # for each variant, we apply 3 epochs. Thus, we will have epoch 1, 2, 3 (or 0, 1, 2 if you starts with 0)
  val_losses = val_loss_list[index]
  plt.plot(epochs,val_losses, label="{0} encoders".format(heads)) # label each line graph with the encoder number (see the actual plotting in the graph below)

plt.legend(); # this turns on the legends, which shows the label for each line graph. You can comment it out and rerun the code to see the difference
plt.show() # show the final figure

# More details of .plot() plotting can be found from: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
for index, heads in enumerate(nhead_list):
  #print(index)
  #print(heads)
  print(val_loss_list[index])
# Out:
# 10.655203954133963
# 10.679729105309772
# 10.588281208794765

# %%
from tabulate import tabulate

table = [['']+['head '+str(i) for i in nhead_list], ['Test ppl']+ppls_list]
print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒══════════╤══════════╤══════════╤══════════╕
# │          │   head 2 │   head 4 │   head 8 │
# ╞══════════╪══════════╪══════════╪══════════╡
# │ Test ppl │  42265.6 │  42752.3 │  39234.4 │
# ╘══════════╧══════════╧══════════╧══════════╛

# %% [markdown]
# ## Sample outputs

# %% [markdown]
# Below are several sample outputs for your reference. The code for deriving the corresponding results will be released in the sample solution later. Your visualization can be different based on your own experiments setups and your intention of visualization.

# %% [markdown]
# ![Image1.png](data:image/png;base64,...)

# %% [markdown]
# ![Image2.png](data:image/png;base64,...)

# %% [markdown]
# ![Image3.png](data:image/png;base64,...)

# %% [markdown]
# ![Image4.png](data:image/png;base64,...)
